# %%
import requests
import pandas as pd
import requests
import os
os.chdir("/Users/apple/Desktop/DEV/portfolio/crypto-app")

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True
